# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import GridSearchCV
from sklearn import set_config; set_config("diagram")

# Create Pipeline
pipeline = Pipeline([
    ('vectorizer', TfidfVectorizer()),
    ('nb', MultinomialNB())
])

# Set parameters to search
param_grid = {
    'vectorizer': [TfidfVectorizer()],
    'vectorizer__ngram_range': [(1,1), (1,2)],   # unigrams or unigrams+bigrams
    'vectorizer__max_df': [0.9, 1.0],            # ignore very common words
    'vectorizer__min_df': [1, 2],                # ignore very rare words
    'nb__alpha': [0.5, 1.0, 1.5]                 # smoothing parameter
}


# Perform grid search on pipeline
grid_search = GridSearchCV(
    pipeline,
    param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

#Fit the grid search:
grid_search.fit(data['data_cleaned'], data['fraudulent'])

#Inspect best estimator:
print("Best score:", grid_search.best_score_)
print("Best parameters:", grid_search.best_params_)
print("Best estimator:", grid_search.best_estimator_)
